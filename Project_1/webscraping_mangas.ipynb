# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# URL de la page à scraper
url = "https://fr.wikipedia.org/wiki/Liste_des_mangas_les_plus_vendus"

# Faire une requête HTTP à la page
response = requests.get(url)

# Vérifier que la requête a réussi
if response.status_code == 200:
    # Analyser le contenu HTML de la page
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Trouver le tableau qui contient les données que vous souhaitez extraire
    target_table = soup.find("table", class_="wikitable")
    
    # Vérifier que le tableau a été trouvé
    if target_table:
        # Initialiser une liste pour stocker les données extraites
        manga_list = []
        
        # Parcourir les lignes du tableau
        for row in target_table.find_all("tr"):  # On exclut la première ligne car c'est l'en-tête du tableau
            # Parcourir les colonnes de chaque ligne
            columns = row.find_all("td")
            if len(columns) >= 3:  # Vérifier qu'il y a au moins 3 colonnes (pour éviter les lignes vides)
                # Extraire les données souhaitées, par exemple les colonnes 1, 2 et 3 (indexées à partir de 0)
                Manga = columns[0].text.strip()
                Auteur = columns[1].text.strip()
                Editeur = columns[2].text.strip()
                Genre = columns[3].text.strip()
                Volume = columns[4].text.strip()
                Parution = columns[5].text.strip()
                vente = columns[6].text.strip()


# Ajouter les données à la liste
                manga_list.append({"Manga" : Manga, "Auteur" : Auteur, "Editeur" : Editeur, 
                                   "Genre" : Genre, "Volume" : Volume, "Parution" : Parution, "vente" : vente})
        
else:
    print("La requête a échoué.")

# %%
df = pd.DataFrame(manga_list)
df
# Out:
#                         Manga                                     Auteur  \
# 0                   One Piece                               Eiichirō Oda
# 1                 Dragon Ball                             Akira Toriyama
# 2                    Golgo 13  Takao SaitōSaito Production (depuis 2021)
# 3             Détective Conan                               Gōshō Aoyama
# 4                      Naruto                          Masashi Kishimoto
# 5                    Doraemon                               Fujiko Fujio
# 6                   Slam Dunk                             Takehiko Inoue
# 7                   KochiKame                              Osamu Akimoto
# 8                Demon Slayer                           Koyoharu Gotouge
# 9            Crayon Shin-chan                               Yoshito Usui
# 10                     Bleach                                  Tite Kubo
# 11                   Oishinbo                 Tetsu KariyaAkira Hanasaki
# 12   JoJo's Bizarre Adventure                             Hirohiko Araki
# 13       L'Attaque des Titans                             Hajime Isayama
# 14           Ken le Survivant                        BuronsonTetsuo Hara
# 15      Astro, le petit robot                               Osamu Tezuka
# 16                      Touch                             Mitsuru Adachi
# 17                       Ippo                            George Morikawa
# 18  Les Enquêtes de Kindaichi    Yōzaburō KanariSeimaru AmagiFumiya Satō
#
#               Editeur          Genre Volume              Parution  \
# 0            Shūeisha         Shōnen    106         1997–en cours
# 1            Shūeisha         Shōnen     42             1984–1995
# 2          Shōgakukan         Gekiga    208         1968–en cours
# 3          Shōgakukan         Shōnen    103         1994–en cours
# 4            Shūeisha         Shōnen     72             1999–2014
# 5          Shōgakukan         Kodomo     45             1969–1996
# 6            Shūeisha         Shōnen     31             1990–1996
# 7            Shūeisha         Shōnen    201             1976–2016
# 8            Shūeisha         Shônen     23             2016–2020
# 9           Futabasha         Seinen     60         1990–en cours
# 10           Shūeisha         Shōnen     74             2001–2016
# 11         Shōgakukan         Seinen    111  1983–2014 (en pause)
# 12           Shūeisha  Shōnen/Seinen    131         1986–en cours
# 13           Kōdansha         Shōnen     34             2009–2021
# 14           Shūeisha         Shōnen     27             1983–1988
# 15  Kōbunsha/Kōdansha         Shōnen     23             1952–1968
# 16         Shōgakukan         Shōnen     26             1981–1986
# 17           Kōdansha         Shōnen    138         1989–en cours
# 18           Kōdansha  Shōnen/Seinen     90         1992–en cours
#
#                          vente
# 0   516,6 millions (tirage)[1]
# 1     330 millions[2],[note 1]
# 2              300 millions[3]
# 3     270 millions (tirage)[4]
# 4     250 millions (tirage)[5]
# 5              250 millions[6]
# 6              170 millions[7]
# 7            156,5 millions[5]
# 8     150 millions (tirage)[8]
# 9     148 millions[9],[note 2]
# 10   130 millions (tirage)[10]
# 11            130 millions[11]
# 12   120 millions (tirage)[12]
# 13   110 millions (tirage)[13]
# 14            100 millions[14]
# 15            100 millions[15]
# 16            100 millions[16]
# 17            100 millions[17]
# 18   100 millions (tirage)[18]

# %% [markdown]
# # Récupération des données : Wikipédia

# %%
dfs = pd.read_html(url)

len(dfs)
# Out:
# 6

# %%
tab_1 = dfs[0]
tab_2 = dfs[1]
tab_3 = dfs[2]
tab_4 = dfs[3]
tab_5 = dfs[4]
tab_6 = dfs[5]

# %%
data = pd.concat([tab_1, tab_2,tab_3,tab_4,tab_5,tab_6])

# %%
data.head()
# Out:
#                          Manga                 Auteur(s)    Éditeur(s)  \
# 11               Darwin's Game                 FLIPFLOPs  Akita Shoten
# 12                  Medaka Box  Nisio IsinAkira Akatsuki      Shūeisha
# 13  Iruma à l'école des démons               Osamu Nishi  Akita Shoten
# 14   Les Brigades Immunitaires             Akane Shimizu      Kōdansha
# 15                      Mashle             Komoto Hajime      Shūeisha
#
#      Genre Volumes Date de parution                 Ventes approximatives
# 11  Shōnen      28    2012–en cours            5.6 millions (tirage)[141]
# 12  Shōnen      22        2009–2013            5,1 millions (tirage)[142]
# 13  Shōnen      32    2017–en cours              5 millions (tirage)[143]
# 14  Shōnen       6        2015–2021  5 millions (tirage)[réf. nécessaire]
# 15  Shōnen      17        2020–2023              5 millions (tirage)[144]

# %%
data.reset_index(inplace = True)

# %%
data.tail()
# Out:
#      index                       Manga                 Auteur(s)  \
# 193     11               Darwin's Game                 FLIPFLOPs
# 194     12                  Medaka Box  Nisio IsinAkira Akatsuki
# 195     13  Iruma à l'école des démons               Osamu Nishi
# 196     14   Les Brigades Immunitaires             Akane Shimizu
# 197     15                      Mashle             Komoto Hajime
#
#        Éditeur(s)   Genre Volumes Date de parution  \
# 193  Akita Shoten  Shōnen      28    2012–en cours
# 194      Shūeisha  Shōnen      22        2009–2013
# 195  Akita Shoten  Shōnen      32    2017–en cours
# 196      Kōdansha  Shōnen       6        2015–2021
# 197      Shūeisha  Shōnen      17        2020–2023
#
#                     Ventes approximatives
# 193            5.6 millions (tirage)[141]
# 194            5,1 millions (tirage)[142]
# 195              5 millions (tirage)[143]
# 196  5 millions (tirage)[réf. nécessaire]
# 197              5 millions (tirage)[144]

# %%
data.drop(['index'], axis=1,inplace = True)

# %%
data.head()
# Out:
#              Manga                                  Auteur(s)  Éditeur(s)  \
# 0        One Piece                               Eiichirō Oda    Shūeisha
# 1      Dragon Ball                             Akira Toriyama    Shūeisha
# 2         Golgo 13  Takao SaitōSaito Production (depuis 2021)  Shōgakukan
# 3  Détective Conan                               Gōshō Aoyama  Shōgakukan
# 4           Naruto                          Masashi Kishimoto    Shūeisha
#
#     Genre Volumes Date de parution       Ventes approximatives
# 0  Shōnen     106    1997–en cours  516,6 millions (tirage)[1]
# 1  Shōnen      42        1984–1995    330 millions[2],[note 1]
# 2  Gekiga     208    1968–en cours             300 millions[3]
# 3  Shōnen     103    1994–en cours    270 millions (tirage)[4]
# 4  Shōnen      72        1999–2014    250 millions (tirage)[5]

# %% [markdown]
# # Exploration des données

# %%
data.describe()
# Out:
#             Manga      Auteur(s) Éditeur(s)   Genre  Volumes Date de parution  \
# count         198            198        198     198      198              198
# unique        198            173         21       9      103              158
# top     One Piece  Naoki Urasawa   Shūeisha  Shōnen       23    2012–en cours
# freq            1              5         78     118        9                4
#
#        Ventes approximatives
# count                    198
# unique                   192
# top           50 millions[5]
# freq                       3

# %%
data.dtypes
# Out:
# Manga                    object
# Auteur(s)                object
# Éditeur(s)               object
# Genre                    object
# Volumes                  object
# Date de parution         object
# Ventes approximatives    object
# dtype: object

# %%
data['Genre'].unique()
# Out:
# array(['Shōnen', 'Gekiga', 'Kodomo', 'Shônen', 'Seinen', 'Shōnen/Seinen',
#        'Josei', 'Shonen', 'Shōjo'], dtype=object)

# %%
data.loc[data['Genre'] == 'Shōnen']
# Out:
#                           Manga                 Auteur(s)    Éditeur(s)  \
# 0                     One Piece              Eiichirō Oda      Shūeisha
# 1                   Dragon Ball            Akira Toriyama      Shūeisha
# 3               Détective Conan              Gōshō Aoyama    Shōgakukan
# 4                        Naruto         Masashi Kishimoto      Shūeisha
# 6                     Slam Dunk            Takehiko Inoue      Shūeisha
# ..                          ...                       ...           ...
# 193               Darwin's Game                 FLIPFLOPs  Akita Shoten
# 194                  Medaka Box  Nisio IsinAkira Akatsuki      Shūeisha
# 195  Iruma à l'école des démons               Osamu Nishi  Akita Shoten
# 196   Les Brigades Immunitaires             Akane Shimizu      Kōdansha
# 197                      Mashle             Komoto Hajime      Shūeisha
#
#       Genre Volumes Date de parution                 Ventes approximatives
# 0    Shōnen     106    1997–en cours            516,6 millions (tirage)[1]
# 1    Shōnen      42        1984–1995              330 millions[2],[note 1]
# 3    Shōnen     103    1994–en cours              270 millions (tirage)[4]
# 4    Shōnen      72        1999–2014              250 millions (tirage)[5]
# 6    Shōnen      31        1990–1996                       170 millions[7]
# ..      ...     ...              ...                                   ...
# 193  Shōnen      28    2012–en cours            5.6 millions (tirage)[141]
# 194  Shōnen      22        2009–2013            5,1 millions (tirage)[142]
# 195  Shōnen      32    2017–en cours              5 millions (tirage)[143]
# 196  Shōnen       6        2015–2021  5 millions (tirage)[réf. nécessaire]
# 197  Shōnen      17        2020–2023              5 millions (tirage)[144]
#
# [118 rows x 7 columns]

# %%
#Uniformisation du terme Shonen
data.replace('Shōnen', 'Shonen', inplace = True)
data.replace('Shônen', 'Shonen', inplace = True)

# %%
data['Genre'].unique()
# Out:
# array(['Shonen', 'Gekiga', 'Kodomo', 'Seinen', 'Shōnen/Seinen', 'Josei',
#        'Shōjo'], dtype=object)
